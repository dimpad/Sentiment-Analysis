# %%
import tweepy
import re
from textblob import TextBlob

# %%
api_key = "QewA9bvw8LWEyAaIVperVvyQ5"
api_secret_key = "vCIEbSmmryZfE5JEzvhM4K2ODYrDU4Im7qvM7TzVlVHCGnLtMs"
access_token = "1147085803375321088-R7bI0Kb0waD1EH8vicAaEhytj3gIGW"
access_token_secret = "Pxy0BVqj8I7aHFxqR3AzFX8uOddEAFYOpLKWIJugsuKjK"

# %%
auth = tweepy.OAuthHandler(api_key, api_secret_key)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
hasilsearch = api.search(q="jakarta", lang="en" ,count= 100) #textblob bisa membaca bahasa ingris,jadi harus dirubah bahasa
hasilsearch
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001E64D26F040>, _json={'created_at': 'Fri Feb 12 06:35:02 +0000 2021', 'id': 1360115177417367554, 'id_str': '1360115177417367554', 'text': '@illegalkimjoon @BTS_twt Dom jakarta\n\nI vote for @BTS_twt for Favorite Global Music Group at the #KCA #VoteBTSGlobal', 'truncated': False, 'entities': {'hashtags': [{'text': 'KCA', 'indices': [97, 101]}, {'text': 'VoteBTSGlobal', 'indices': [102, 116]}], 'symbols': [], 'user_mentions': [{'screen_name': 'illegalkimjoon', 'name': 'bie🍒🌸✯', 'id': 792252345698496512, 'id_str': '792252345698496512', 'indices': [0, 15]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [16, 24]}, {'screen_name': 'BTS_twt', 'name': '방탄소년단', 'id': 335141638, 'id_str': '335141638', 'indices': [49, 57]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in
# ...

# %%
for tweet in hasilsearch:
  tweet_properties = {}
  tweet_properties["tanggal_tweet"] = tweet.created_at
  tweet_properties["pengguna"] = tweet.user.screen_name
  tweet_properties["isi_tweet"] = tweet.text
  remove =' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",tweet.text).split()) #menghilangkan @,link,dsb
  print(remove)
# Out:
# twt Dom jakarta I vote for twt for Favorite Global Music Group at the KCA VoteBTSGlobal
# RT Hi We ve booked LED for Win s BD on 21st Feb Locations 1 Plaza Atrium Senen Jakarta 2 Plasa Te
# RT Hi my Shopee is now open for local orders guys Shipping from Jakarta Price idr 10 15k each no minimum order Size
# Julian is still in the plane on his way back to Jakarta and he has another work to finish It s one AM and everyon
# RT rts are appreciated WTS PC Renjun arrival ver 125k include packing Jakarta Bisa shopee amp keep 25 2 3 3 Cross
# Anak Elang Harley Davidson sincerely wish you happiness cheerfulness and success in the upcoming year Happy Chin
# RT Hi We ve booked LED for Win s BD on 21st Feb Locations 1 Plaza Atrium Senen Jakarta 2 Plasa Te
# RT rts are appreciated WTS PC Renjun arrival ver 125k include packing Jakarta Bisa shopee amp keep 25 2 3 3 Cross
# HELP RT bismillah kali aja kejual INA ONLY Jakarta Timur Not in a rush WTS POLAROID SKZ IN JEONGIN GO LIVE
# ...

# %%
analysis = TextBlob(remove)
print(type(analysis))
# Out:
# <class 'textblob.blob.TextBlob'>

# %%
print(analysis.sentiment.polarity)

if analysis.sentiment.polarity > 0.0:
    tweet_properties["sentimen"]= "positif"
elif analysis.sentiment.polarity == 0.0:
    tweet_properties["sentimen"]= "netral"
if analysis.sentiment.polarity < 0.0:
    tweet_properties["sentimen"]= "negatif"
print(tweet_properties)
# Out:
# 0.4
# {'tanggal_tweet': datetime.datetime(2021, 2, 12, 6, 6, 41), 'pengguna': 'majicty', 'isi_tweet': "RT @ShinaeTaz: Hi, We've booked LED for Win's BD on 21st Feb. Locations:\n1. Plaza Atrium Senen, Jakarta\nhttps://t.co/X4R6nWZ3UO\n2. Plasa Te…", 'sentimen': 'positif'}
